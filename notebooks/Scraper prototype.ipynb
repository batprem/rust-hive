# %%
# !uv add beautifulsoup4
# !uv add result
# !uv add pandas
# Out:
# Resolved 110 packages in 0.32ms
# Audited 106 packages in 0.05ms
# Resolved 110 packages in 0.33ms
# Audited 106 packages in 0.05ms

# %%
import requests
from result import Ok, Err, Result, is_ok, is_err
import duckdb
from pathlib import Path


def create_duck_db_table():
    duckdb.sql("""CREATE OR REPLACE TABLE

    thai_population
    (
        data_year INTEGER,
        yymm VARCHAR,
        cc_code INTEGER,
        cc_desc VARCHAR,
        rcode_code VARCHAR,
        rcode_desc VARCHAR,
        ccaatt_code VARCHAR,
        ccaatt_desc VARCHAR,
        ccaattmm_code VARCHAR,
        ccaattmm_desc VARCHAR,
        male INTEGER,
        female INTEGER,
        total INTEGER,
        house INTEGER,
        PRIMARY KEY (data_year, cc_code)
    );""")
    
def generate_insert_sql(
    data_year: int,
    yymm: str,
    cc_code: int,
    cc_desc: str,
    rcode_code: str,
    rcode_desc: str,
    ccaatt_code: str,
    ccaatt_desc: str,
    ccaattmm_code: str,
    ccaattmm_desc: str,
    male: int,
    female: int,
    total: int,
    house: int,
) -> str:

    return f"""INSERT INTO thai_population
VALUES (
    '{data_year}',
    '{yymm}',
    '{cc_code}',
    '{cc_desc}',
    '{rcode_code}',
    '{rcode_desc}',
    '{ccaatt_code}',
    '{ccaatt_desc}',
    '{ccaattmm_code}',
    '{ccaattmm_desc}',
    '{male}',
    '{female}',
    '{total}',
    '{house}'
)"""

def write_into_hive_partition():
    

    Path(".datasets").mkdir(parents=True, exist_ok=True)
    duckdb.sql("""COPY thai_population
TO
    './datasets/thai_population'
    (
        FORMAT PARQUET,
        PARTITION_BY (data_year),
        OVERWRITE_OR_IGNORE,
        COMPRESSION GZIP,
        FILE_EXTENSION 'parquet.gz'
    )
""")
write_into_hive_partition()

def convert_to_thai_year(year: int) -> int:
    """Convert year into shortened Thai year

    Args:
        year (int) - Year such as 2024
    Returns:
        int - (Thai year)
    """
    return (year + 543) - 2500

def get_data_stat_by_year(year: int) -> Result[str, str]:
    thai_year = convert_to_thai_year(year) 
    url = f"https://stat.bora.dopa.go.th/new_stat/file/{thai_year}/stat_c{thai_year}.txt"
    response = requests.get(url)
    if not response.ok:
        return Err(response.text)
    else:
        return Ok(response.text)


def clean_text(text: str) -> str:
    return text.strip("\ufeff")


def extract_row(row: str) -> list[str]:
    return row.split("|")

def string_to_int(value: str) -> int:
    return int(value.replace(",", ""))



year = 1993


# Create table
create_duck_db_table()
while True:
    

    # Match pattern
    match get_data_stat_by_year(year):
        case Ok(value):
            ...
        case  Err(e):
            break
    # Create a data structure
    table = clean_text(value)
    
    # Insert into the table
    for row in table.splitlines():
        (
            yymm,
            cc_code,
            cc_desc,
            rcode_code,
            rcode_desc,
            ccaatt_code,
            ccaatt_desc,
            ccaattmm_code,
            ccaattmm_desc,
            male_str,
            female_str,
            total_str,
            house_str,
        ) = extract_row(row.strip("|"))
        sql_syntax = generate_insert_sql(
            year,
            yymm,
            string_to_int(cc_code),
            cc_desc,
            rcode_code,
            rcode_desc,
            ccaatt_code,
            ccaatt_desc,
            ccaattmm_code,
            ccaattmm_desc,
            string_to_int(male_str),
            string_to_int(female_str),
            string_to_int(total_str),
            string_to_int(house_str),
        )
        duckdb.sql(sql_syntax)
    year += 1

# %%
duckdb.sql("""SELECT *
FROM read_parquet('./datasets/thai_population/*/*.parquet.gz', hive_partitioning = true);
""").to_df()
# Out:
#       yymm  cc_code              cc_desc rcode_code rcode_desc ccaatt_code  \
# 0     3612        0           ทั่วประเทศ          0                      0
# 1     3612       10        กรุงเทพมหานคร          0                      0
# 2     3612       11  จังหวัดสมุทรปราการ           0                      0
# 3     3612       12      จังหวัดนนทบุรี           0                      0
# 4     3612       13     จังหวัดปทุมธานี           0                      0
# ...    ...      ...                  ...        ...        ...         ...
# 2395  6612       92         จังหวัดตรัง           0                      0
# 2396  6612       93       จังหวัดพัทลุง           0                      0
# 2397  6612       94      จังหวัดปัตตานี           0                      0
# 2398  6612       95         จังหวัดยะลา           0                      0
# 2399  6612       96     จังหวัดนราธิวาส           0                      0
#
#      ccaatt_desc ccaattmm_code ccaattmm_desc      male    female     total  \
# 0                            0                29205086  29130986  58336072
# 1                            0                 2760480   2812232   5572712
# 2                            0                  442043    453341    895384
# 3                            0                  352531    364874    717405
# 4                            0                  247964    252122    500086
# ...          ...           ...           ...       ...       ...       ...
# 2395                         0                  311212    325805    637017
# 2396                         0                  253232    267366    520598
# 2397                         0                  364396    372681    737077
# 2398                         0                  273248    276698    549946
# 2399                         0                  405170    413992    819162
#
#          house  data_year
# 0     13336167       1993
# 1      1472621       1993
# 2       267935       1993
# 3       224651       1993
# 4       160164       1993
# ...        ...        ...
# 2395    243956       2023
# 2396    205036       2023
# 2397    204902       2023
# 2398    178717       2023
# 2399    229831       2023
#
# [2400 rows x 14 columns]

# %%
# Out:
# Resolved 114 packages in 1.20s
# ⠙ Preparing packages... (0/4)                                                   ⠋ Resolving dependencies...
# ⠙ Preparing packages... (0/4)----     0 B/338.46 KiB
# tzdata     ------------------------------     0 B/338.46 KiB
# ⠙ Preparing packages... (0/4)----     0 B/496.10 KiB
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)----     0 B/496.10 KiB
# tzdata     ------------------------------ 32.00 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)----     0 B/496.10 KiB
# tzdata     ------------------------------ 48.00 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)----     0 B/496.10 KiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)----     0 B/496.10 KiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)---- 16.00 KiB/496.10 KiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)---- 32.00 KiB/496.10 KiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# ⠙ Preparing packages... (0/4)---- 48.00 KiB/496.10 KiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# ⠙ Preparing packages... (0/4)----     0 B/5.14 MiB
# tzdata     ------------------------------ 63.09 KiB/338.46 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# numpy      ------------------------------     0 B/5.14 MiB
# ⠙ Preparing packages... (0/4)----     0 B/10.80 MiB
# tzdata     ------------------------------ 79.09 KiB/338.46 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# numpy      ------------------------------     0 B/5.14 MiB
# ⠙ Preparing packages... (0/4)----     0 B/10.80 MiB
# tzdata     ------------------------------ 79.09 KiB/338.46 KiB
# pytz       ------------------------------ 63.82 KiB/496.10 KiB
# numpy      ------------------------------     0 B/5.14 MiB
# ⠙ Preparing packages... (0/4)----     0 B/10.80 MiB
# tzdata     ------------------------------ 79.09 KiB/338.46 KiB
# pytz       ------------------------------ 63.82 KiB/496.10 KiB
# numpy      ------------------------------ 16.00 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)----     0 B/10.80 MiB
# tzdata     ------------------------------ 79.09 KiB/338.46 KiB
# pytz       ------------------------------ 63.82 KiB/496.10 KiB
# numpy      ------------------------------ 16.00 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)---- 16.00 KiB/10.80 MiB
# tzdata     ------------------------------ 79.09 KiB/338.46 KiB
# pytz       ------------------------------ 79.82 KiB/496.10 KiB
# numpy      ------------------------------ 16.00 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)---- 16.00 KiB/10.80 MiB
# tzdata     ------------------------------ 95.09 KiB/338.46 KiB
# pytz       ------------------------------ 79.82 KiB/496.10 KiB
# numpy      ------------------------------ 16.00 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)---- 16.00 KiB/10.80 MiB
# tzdata     ------------------------------ 95.09 KiB/338.46 KiB
# pytz       ------------------------------ 95.82 KiB/496.10 KiB
# numpy      ------------------------------ 16.00 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)---- 16.00 KiB/10.80 MiB
# tzdata     ------------------------------ 143.09 KiB/338.46 KiB
# pytz       ------------------------------ 159.82 KiB/496.10 KiB
# numpy      ------------------------------ 255.89 KiB/5.14 MiB
# ⠙ Preparing packages... (0/4)---- 256.00 KiB/10.80 MiB
# tzdata     ------------------------------ 159.09 KiB/338.46 KiB
# pytz       ------------------------------ 175.82 KiB/496.10 KiB
# numpy      ------------------------------ 288.00 KiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 592.00 KiB/10.80 MiB
# tzdata     ------------------------------ 190.99 KiB/338.46 KiB
# pytz       ------------------------------ 239.82 KiB/496.10 KiB
# numpy      ------------------------------ 384.00 KiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 960.00 KiB/10.80 MiB
# tzdata     ------------------------------ 207.09 KiB/338.46 KiB
# pytz       ------------------------------ 271.82 KiB/496.10 KiB
# numpy      ------------------------------ 1.03 MiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 1.37 MiB/10.80 MiB
# tzdata     ------------------------------ 271.09 KiB/338.46 KiB
# pytz       ------------------------------ 399.82 KiB/496.10 KiB
# numpy      ------------------------------ 2.53 MiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 1.88 MiB/10.80 MiB
# pytz       ------------------------------ 415.82 KiB/496.10 KiB
# numpy      ------------------------------ 2.86 MiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 1.93 MiB/10.80 MiB
# numpy      ------------------------------ 2.94 MiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 2.11 MiB/10.80 MiB
# numpy      ------------------------------ 3.14 MiB/5.14 MiB
# ⠹ Preparing packages... (0/4)---- 2.50 MiB/10.80 MiB
# numpy      ------------------------------ 4.42 MiB/5.14 MiB
# ⠸ Preparing packages... (2/4)---- 3.14 MiB/10.80 MiB
# ⠸ Preparing packages... (2/4)---- 3.47 MiB/10.80 MiB
# ⠸ Preparing packages... (2/4)---- 3.76 MiB/10.80 MiB
# ⠸ Preparing packages... (2/4)---- 5.58 MiB/10.80 MiB
# Prepared 4 packages in 563ms
# Installed 4 packages in 48ms
#  + numpy==2.2.0
#  + pandas==2.2.3
#  + pytz==2024.2
#  + tzdata==2024.2

# %%
x1 = "6212|95|จังหวัดยะลา |0| |0| |0| |266,860|269,470|536,330|167,137|".strip("|").split("|")
len(x1)
# Out:
# 13

# %%
x2 = "6312|0|ทั่วประเทศ|0| |0| |0| |32,375,532|33,811,195|66,186,727|27,224,743|".strip("|").split("|")
len(x2)
# Out:
# 13
